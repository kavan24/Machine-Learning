# %%
#Import scikit-learn dataset library
from sklearn import datasets

# %%
#Load dataset
cancer = datasets.load_breast_cancer()

# %%
cancer.data
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, ..., 2.654e-01, 4.601e-01,
#         1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, ..., 1.860e-01, 2.750e-01,
#         8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, ..., 2.430e-01, 3.613e-01,
#         8.758e-02],
#        ...,
#        [1.660e+01, 2.808e+01, 1.083e+02, ..., 1.418e-01, 2.218e-01,
#         7.820e-02],
#        [2.060e+01, 2.933e+01, 1.401e+02, ..., 2.650e-01, 4.087e-01,
#         1.240e-01],
#        [7.760e+00, 2.454e+01, 4.792e+01, ..., 0.000e+00, 2.871e-01,
#         7.039e-02]])

# %%
cancer.data[0]
# Out:
# array([1.799e+01, 1.038e+01, 1.228e+02, 1.001e+03, 1.184e-01, 2.776e-01,
#        3.001e-01, 1.471e-01, 2.419e-01, 7.871e-02, 1.095e+00, 9.053e-01,
#        8.589e+00, 1.534e+02, 6.399e-03, 4.904e-02, 5.373e-02, 1.587e-02,
#        3.003e-02, 6.193e-03, 2.538e+01, 1.733e+01, 1.846e+02, 2.019e+03,
#        1.622e-01, 6.656e-01, 7.119e-01, 2.654e-01, 4.601e-01, 1.189e-01])

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, test_size=0.3,random_state=109) # 70% training and 30% test

# %%
#Import svm model
from sklearn import svm

# %%
#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

# %%
#Train the model using the training sets
clf.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# %%
# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9649122807017544

# %%
x1=[2.5,3,2.3,3.3,2.5]
y1=[2.6,3,2,2.3,1.6]
x2=[1.8,1.9,2.7,3.3,3.6,3.5,3,2.5]
y2=[1.5,3,3.5,3.4,2.5,1.5,1,0.8]

# %%
x1=[2.5*2.5,3*3,2.3*2.3,3.3*3.3,2.5*2.5]
y1=[2.6,3,2,2.3,1.6]
x2=[1.8*1.8,1.9*1.9,2.7*2.7,3.3*3.3,3.6*3.6,3.5*3.5,3*3,2.5*2.5]
y2=[1.5,3,3.5,3.4,2.5,1.5,1,0.8]

# %%
from matplotlib import pyplot as plt
plt.scatter(x1,y1,color='red')
plt.scatter(x2,y2,color='blue')

# %%
import numpy as np

# %%
x1=np.array([-2,-2,1,2,2,1.5])
y1=np.array([2,-1.5,3,1.5,-2,-3])
x2=np.array([-3,-3.5,-3.5,-4,2,3.5,5,5,3.5])
y2=np.array([-5,-2,4,2,5,3.5,1,-3.5,-5.5])

# %%
from matplotlib import pyplot as plt
plt.scatter(x1,y1,color='red')
plt.scatter(x2,y2,color='blue')

# %%
x1=np.array([-2*-2,-2*-2,1*1,2*2,2*2,1.5*1.5])
y1=np.array([2*2,-1.5*-1.5,3*3,1.5*1.5,-2*-2,-3*-3])
x2=np.array([-3*-3,-3.5*-3.5,-3.5*-3.5,-4*-4,2*2,3.5*3.5,5*5,5*5,3.5*3.5])
y2=np.array([-5*-5,-2*-2,4*4,2*2,5*5,3.5*3.5,1*1,-3.5*-3.5,-5.5*-5.5])

# %%
from matplotlib import pyplot as plt
plt.scatter(x1,y1,color='red')
plt.scatter(x2,y2,color='blue')

# %%
x1=np.array([0,3])
y1=np.array([3,0])
x2=np.array([1,2])
y2=np.array([2,1])

# %%
from matplotlib import pyplot as plt
plt.scatter(x1,y1,color='red')
plt.scatter(x2,y2,color='blue')

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = pyplot.figure()
ax = Axes3D(fig)

# %%
fig = pyplot.figure()
ax = Axes3D(fig)
x1=np.array([0,3])
y1=np.array([3,0])
z1=np.array([3,3])
x2=np.array([1,2])
y2=np.array([2,1])
z2=np.array([2,2])
ax.scatter(x1,y1,z1,color='red')
ax.scatter(x2,y2,z2,color='blue')
pyplot.show()
